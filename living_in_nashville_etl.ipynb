# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
# Load the data
file_path = ('Park_Locations_cleaned.csv')
df = pd.read_csv(file_path)

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()

# %%
df.head()
# Out:
#                          Park Name  Zip Codes   Acres  Year Established  \
# 0                     Antioch Park      37013    7.98              1950
# 1                  Cane Ridge Park      37013  274.13              1983
# 2         Cecil Rhea Crawford Park      37013    6.25              1971
# 4  Southeast Community Center Park      37013   12.14              2014
# 5            William A. Pitts Park      37013   26.94              1982
#
#   Community Center Nature Center Playground ADA Accessible  \
# 0              Yes            No        Yes            Yes
# 1               No            No        Yes            Yes
# 2               No            No        Yes             No
# 4              Yes            No        Yes            Yes
# 5               No            No        Yes            Yes
#
#   Restrooms Available Picnic Shelters  ...  Camping Available by Permit  \
# 0                 Yes             Yes  ...                           No
# ...

# %%
# Remove the unwanted columns
df.drop(columns=['Year Established',
        'Picnic Shelters',
        'Picnic Shelters Quantity',
        'Volleyball',
        'Skate Park',
        'Spray Park',
        'Hiking Trails',
        'Horse Trails',
        'Mountain Bike Trails',
        'Boat Launch',
        'Camping Available by Permit',
        'Fishing by Permit',
        'Lake',
        'Canoe Launch',
        'Community Garden',
        'Notes'])
# Out:
#                            Park Name  Zip Codes    Acres Community Center  \
# 0                       Antioch Park      37013     7.98              Yes
# 1                    Cane Ridge Park      37013   274.13               No
# 2           Cecil Rhea Crawford Park      37013     6.25               No
# 4    Southeast Community Center Park      37013    12.14              Yes
# 5              William A. Pitts Park      37013    26.94               No
# ..                               ...        ...      ...              ...
# 107               Harpeth Knoll Park      37221     9.88               No
# 108               Harpeth River Park      37221    69.86               No
# 109                Percy Warner Park      37221  1991.56               No
# 110                  Ted Rhodes Park      37228   261.17               No
# 111               Public Square Park      37243     6.01               No
#
#     Nature Center Playground ADA Accessible Restrooms Available Dog Park  \
# ...

# %%
df.head()

# %%
df.to_csv('Park_Locations_etl.csv')

# %%
File Break--------------

# %%
# Load the data
file_path = ('MNPS Enrollment Data 060121.csv')
df = pd.read_csv(file_path)

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
# df = df.dropna()

# %%
df.head()
# Out:
#   School Year       School Level  School ID                School Name  \
# 0       20-21  Elementary School        496    A. Z. Kelley Elementary
# 1       20-21  Elementary School        375      Alex Green Elementary
# 2       20-21  Elementary School        105           Amqui Elementary
# 3       20-21  Elementary School        460  Andrew Jackson Elementary
# 4       20-21        High School        110        Antioch High School
#
#    State School ID  Zip Code  Rank Great schools rating  Total Enrollment  \
# 0                1     37013   4.0        Below Average               745
# 1                5     37189   3.0        Below Average               313
# 2               10     37115   5.0              Average               445
# 3               15     37138   7.0        Above Average               409
# 4               20     37013   2.0        Below Average              1894
#
#   Grade PreK 3yrs  ... Black or African American Hispanic/Latino  \
# ...

# %%
# Remove the unwanted columns
df.drop(columns=['School Year',
                 'School ID',
                 'State School ID',
                 'Grade PreK 3yrs',
                 'Grade PreK 4yrs',
                 'Grade K',
                 'Grade 1',
                 'Grade 2',
                 'Grade 3',
                 'Grade 4',
                 'Grade 5',
                 'Grade 6',
                 'Grade 7',
                 'Grade 8',
                 'Grade 9',
                 'Grade 10',
                 'Grade 11',
                 'Grade 12',
                 'Male',
                 'Female',
                 'Economically Disadvantaged',
                 'Limited English Proficiency',
                 'DataAsOf'])
# Out:
#           School Level                  School Name  Zip Code  Rank  \
# 0    Elementary School      A. Z. Kelley Elementary     37013   4.0
# 1    Elementary School        Alex Green Elementary     37189   3.0
# 2    Elementary School             Amqui Elementary     37115   5.0
# 3    Elementary School    Andrew Jackson Elementary     37138   7.0
# 4          High School          Antioch High School     37013   2.0
# ..                 ...                          ...       ...   ...
# 157      Middle School              West End Middle     37205   4.0
# 158  Elementary School         Westmeade Elementary     37205   6.0
# 159        High School     Whites Creek High School     37189   1.0
# 160      Middle School  William Henry Oliver Middle     37211   5.0
# 161      Middle School                Wright Middle     37211   3.0
#
#     Great schools rating  Total Enrollment American Indian or Alaska Native  \
# ...

# %%
df.to_csv('MNPS_Enrollment_Data_060121_etl.csv')

# %%
File Break--------------

# %%
# Load the data
file_path = ('Nashville_housing_data_2013_2016.csv')
df = pd.read_csv(file_path)

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
# df = df.dropna()
# Out:
# C:\Users\anyone\anaconda3\envs\Pydata\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        Parcel ID       Land Use  \
# 0         150           150  128 10 0 034.00  SINGLE FAMILY
# 1         151           151  128 10 0 181.00         DUPLEX
# 2         231           231  127 00 0 173.00  SINGLE FAMILY
# 3         245           245  041 11 0 011.00  SINGLE FAMILY
# 4         246           246  041 15 0 043.00  SINGLE FAMILY
#
#      Property Address Suite/ Condo # Property City  Zip Code  Sale Date  \
# 0       620  HICKS RD            NaN     NASHVILLE       0.0  1/24/2013
# 1       645  HICKS RD            NaN     NASHVILLE       0.0  1/18/2013
# 2  7426  HUNTWICK TRL            NaN     NASHVILLE       0.0  1/10/2013
# 3  4021  DUMBARTON DR            NaN     NASHVILLE       0.0   1/4/2013
# 4  1313  BELLSHIRE DR            NaN     NASHVILLE       0.0  1/31/2013
#
#    Sale Price  ... Building Value Total Value Finished Area Foundation Type  \
# 0      150000  ...       109400.0    145400.0    1900.00000            SLAB
# ...

# %%
# Remove the unwanted columns
df.drop(columns=['Unnamed: 0',
                 'Unnamed: 0.1',
                 'Suite/ Condo #',
                 'Sale Date',
                 'Sold As Vacant',
                 'Multiple Parcels Involved in Sale',
                 'Owner Name',
                 'Address',
                 'City',
                 'State',
                 'Acreage',
                 'Tax District',
                 'Neighborhood',
                 'image',
                 'Land Value',
                 'Building Value',
                 'Total Value',
                 'Foundation Type',
                 'Year Built',
                 'Exterior Wall',
                 'Grade'])
# Out:
#              Parcel ID                 Land Use    Property Address  \
# 0      128 10 0 034.00            SINGLE FAMILY       620  HICKS RD
# 1      128 10 0 181.00                   DUPLEX       645  HICKS RD
# 2      127 00 0 173.00            SINGLE FAMILY  7426  HUNTWICK TRL
# 3      041 11 0 011.00            SINGLE FAMILY  4021  DUMBARTON DR
# 4      041 15 0 043.00            SINGLE FAMILY  1313  BELLSHIRE DR
# ...                ...                      ...                 ...
# 56631  131 06 0 022.00            SINGLE FAMILY                 NaN
# 56632  072 11 0 177.00  VACANT RESIDENTIAL LAND                 NaN
# 56633  072 11 0 402.00  VACANT RESIDENTIAL LAND                 NaN
# 56634  116 04 0 118.00            SINGLE FAMILY                 NaN
# 56635  072 15 0 176.00            SINGLE FAMILY                 NaN
#
#       Property City  Zip Code  Sale Price   Legal Reference  Finished Area  \
# ...

# %%
df.to_csv('Nashville_housing_data_2013_2016_etl.csv')
